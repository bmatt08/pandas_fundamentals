# %%
#Combining Data

# %%
import pandas as pd

# %%
#Importing DataSets
climate_temp = pd.read_csv("climate_temp.csv")
climate_precip = pd.read_csv("climate_precip.csv")

# %%
climate_temp.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  DLY-CLDD-BASE72  \
# 0            -7777  ...                0                0                0
# 1            -7777  ...                0                0                0
# 2            -7777  ...                0                0                0
# 3            -7777  ...                0                0                0
# 4            -7777  ...                0                0                0
#
#    DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  DLY-HTDD-BASE55  \
# 0            -7777                1                2                6
# 1            -7777                1                2                6
# 2            -7777                1                2                5
# 3            -7777                1                2                5
# 4            -7777            -7777                2                5
#
#    DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0                7               10               15
# 1                7               10               15
# 2                7               10               15
# 3                7               10               15
# 4                7               10               15
#
# [5 rows x 21 columns]

# %%
climate_precip.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# 0            -66.6            -6.66  ...                        3
# 1            -66.6            -6.66  ...                        3
# 2            -66.6            -6.66  ...                        3
# 3          -9999.0            -6.66  ...                        3
# 4          -9999.0            -6.66  ...                        3
#
#    DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  DLY-SNWD-PCTALL-GE003WI  \
# 0                    -9999                        0                    -9999
# 1                    -9999                        0                    -9999
# 2                    -9999                        0                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNWD-PCTALL-GE005WI  DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 0                    -9999                    -9999                    -9999
# 1                    -9999                    -9999                    -9999
# 2                    -9999                    -9999                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  DLY-SNOW-PCTALL-GE050TI
# 0                        0                    -9999                    -9999
# 1                        0                    -9999                    -9999
# 2                        0                    -9999                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
# [5 rows x 29 columns]

# %%
#127,020 rows
#21 columns
climate_temp.shape
# Out:
# (127020, 21)

# %%
#151,110 rows
#29 columns
climate_precip.shape
# Out:
# (151110, 29)

# %%
#Inner Join

# %%
#Selecting rows that only "STATION" field has GHCND:USC00045721
precip_one_station = climate_precip.query("STATION == 'GHCND:USC00045721'")
precip_one_station.head()
# Out:
#                 STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#       DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 1460             -666            -66.6             0.16             -666
# 1461             -666            -66.6             0.16             -666
# 1462             -666            -66.6             0.16             -666
# 1463             -666            -66.6             0.16             -666
# 1464             -666            -66.6             0.17             -666
#
#       DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# 1460            -66.6             0.44  ...                       11
# 1461            -66.6             0.44  ...                       11
# 1462            -66.6             0.45  ...                       11
# 1463            -66.6             0.45  ...                       11
# 1464            -66.6             0.46  ...                       11
#
#       DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  \
# 1460                        4                        0
# 1461                        4                        0
# 1462                        4                        0
# 1463                        4                        0
# 1464                        4                        0
#
#       DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 1460                        3                        3
# 1461                        3                        3
# 1462                        3                        3
# 1463                        3                        2
# 1464                        3                        2
#
#       DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 1460                        9                        6
# 1461                       10                        6
# 1462                       10                        6
# 1463                       10                        6
# 1464                       10                        6
#
#       DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  \
# 1460                        0                    -9999
# 1461                        0                    -9999
# 1462                        0                    -9999
# 1463                        0                    -9999
# 1464                        0                    -9999
#
#       DLY-SNOW-PCTALL-GE050TI
# 1460                    -9999
# 1461                    -9999
# 1462                    -9999
# 1463                    -9999
# 1464                    -9999
#
# [5 rows x 29 columns]

# %%
precip_one_station.shape
# Out:
# (365, 29)

# %%
inner_merged = pd.merge(precip_one_station, climate_temp)
inner_merged.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6             0.16             -666
# 1             -666            -66.6             0.16             -666
# 2             -666            -66.6             0.16             -666
# 3             -666            -66.6             0.16             -666
# 4             -666            -66.6             0.17             -666
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0            -66.6             0.44  ...                0                0
# 1            -66.6             0.44  ...                0                0
# 2            -66.6             0.45  ...                0                0
# 3            -66.6             0.45  ...                0                0
# 4            -66.6             0.46  ...                0                0
#
#    DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0                0                1                3                6
# 1                0                1                3                6
# 2                0                1                2                5
# 3                0                1                2                5
# 4                0                1                2                5
#
#    DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0               10               12               14               19
# 1               10               11               14               19
# 2                9               11               14               19
# 3                9               11               14               19
# 4                9               11               14               19
#
# [5 rows x 47 columns]

# %%
inner_merged.shape
# Out:
# (365, 47)

# %%
#Merging both entire datasets only on "STATION" & "DATE"
inner_merged_total = pd.merge(
    climate_temp, climate_precip, on = ["STATION", "DATE"]
)
inner_merged_total.head()
# Out:
#              STATION          STATION_NAME_x ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  DLY-SNWD-PCTALL-GE001WI  \
# 0            -7777  ...                        3                    -9999
# 1            -7777  ...                        3                    -9999
# 2            -7777  ...                        3                    -9999
# 3            -7777  ...                        3                        0
# 4            -7777  ...                        3                        0
#
#    DLY-SNWD-PCTALL-GE010WI  DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 0                        0                    -9999                    -9999
# 1                        0                    -9999                    -9999
# 2                        0                    -9999                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  DLY-SNOW-PCTALL-GE100TI  \
# 0                    -9999                    -9999                        0
# 1                    -9999                    -9999                        0
# 2                    -9999                    -9999                        0
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNOW-PCTALL-GE030TI  DLY-SNOW-PCTALL-GE050TI
# 0                    -9999                    -9999
# 1                    -9999                    -9999
# 2                    -9999                    -9999
# 3                        0                        0
# 4                        0                        0
#
# [5 rows x 48 columns]

# %%
inner_merged_total.shape
# Out:
# (123005, 48)

# %%
#Outer Join

# %%
outer_merged = pd.merge(
    precip_one_station, climate_temp, how = "outer", on = ["STATION", "DATE"]
)
outer_merged.head()
# Out:
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0           -666.0            -66.6             0.16           -666.0
# 1           -666.0            -66.6             0.16           -666.0
# 2           -666.0            -66.6             0.16           -666.0
# 3           -666.0            -66.6             0.16           -666.0
# 4           -666.0            -66.6             0.17           -666.0
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0            -66.6             0.44  ...                0                0
# 1            -66.6             0.44  ...                0                0
# 2            -66.6             0.45  ...                0                0
# 3            -66.6             0.45  ...                0                0
# 4            -66.6             0.46  ...                0                0
#
#    DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0                0                1                3                6
# 1                0                1                3                6
# 2                0                1                2                5
# 3                0                1                2                5
# 4                0                1                2                5
#
#    DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0               10               12               14               19
# 1               10               11               14               19
# 2                9               11               14               19
# 3                9               11               14               19
# 4                9               11               14               19
#
# [5 rows x 48 columns]

# %%
outer_merged.shape
# Out:
# (127020, 48)

# %%
#Left Join

# %%
#Merging all DataFrame from the left 
#while removing rows from the DataFrame on the right that doesn't match any columns from the left DataFrame
left_merged = pd.merge(
    climate_temp, precip_one_station, how = "left", on = ["STATION", "DATE"]
)
left_merged.head()
# Out:
#              STATION          STATION_NAME_x ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  DLY-SNWD-PCTALL-GE001WI  \
# 0            -7777  ...                      NaN                      NaN
# 1            -7777  ...                      NaN                      NaN
# 2            -7777  ...                      NaN                      NaN
# 3            -7777  ...                      NaN                      NaN
# 4            -7777  ...                      NaN                      NaN
#
#    DLY-SNWD-PCTALL-GE010WI  DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  DLY-SNOW-PCTALL-GE100TI  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    DLY-SNOW-PCTALL-GE030TI  DLY-SNOW-PCTALL-GE050TI
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
# [5 rows x 48 columns]

# %%
left_merged.shape
# Out:
# (127020, 48)

# %%
left_merged_reversed = pd.merge(
    precip_one_station, climate_temp, how = "left", on = ["STATION", "DATE"]
)
left_merged_reversed.head()
# Out:
#              STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6             0.16             -666
# 1             -666            -66.6             0.16             -666
# 2             -666            -66.6             0.16             -666
# 3             -666            -66.6             0.16             -666
# 4             -666            -66.6             0.17             -666
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0            -66.6             0.44  ...                0                0
# 1            -66.6             0.44  ...                0                0
# 2            -66.6             0.45  ...                0                0
# 3            -66.6             0.45  ...                0                0
# 4            -66.6             0.46  ...                0                0
#
#    DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0                0                1                3                6
# 1                0                1                3                6
# 2                0                1                2                5
# 3                0                1                2                5
# 4                0                1                2                5
#
#    DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0               10               12               14               19
# 1               10               11               14               19
# 2                9               11               14               19
# 3                9               11               14               19
# 4                9               11               14               19
#
# [5 rows x 48 columns]

# %%
left_merged_reversed.shape
# Out:
# (365, 48)

# %%
#Right Join

# %%
#Merging all DataFrame from the right 
#while removing rows from the DataFrame on the left that doesn't match any columns from the right DataFrame
right_merged = pd.merge(
    precip_one_station, climate_temp, how = "right", on = ["STATION", "DATE"]
)
right_merged.head()
# Out:
#              STATION STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099            NaN  20100101              NaN
# 1  GHCND:USC00049099            NaN  20100102              NaN
# 2  GHCND:USC00049099            NaN  20100103              NaN
# 3  GHCND:USC00049099            NaN  20100104              NaN
# 4  GHCND:USC00049099            NaN  20100105              NaN
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0              NaN              NaN  ...                0                0
# 1              NaN              NaN  ...                0                0
# 2              NaN              NaN  ...                0                0
# 3              NaN              NaN  ...                0                0
# 4              NaN              NaN  ...                0                0
#
#    DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0                0            -7777                1                2
# 1                0            -7777                1                2
# 2                0            -7777                1                2
# 3                0            -7777                1                2
# 4                0            -7777            -7777                2
#
#    DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0                6                7               10               15
# 1                6                7               10               15
# 2                5                7               10               15
# 3                5                7               10               15
# 4                5                7               10               15
#
# [5 rows x 48 columns]

# %%
right_merged.shape
# Out:
# (127020, 48)

# %%
#Combining Data across rows or columns

# %%
#Concatenating both entire DataFrames
outer_joined = pd.concat([climate_precip, climate_temp])
outer_joined.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0           -666.0            -66.6            -6.66           -666.0
# 1           -666.0            -66.6            -6.66           -666.0
# 2           -666.0            -66.6            -6.66           -666.0
# 3          -9999.0          -9999.0            -6.66          -9999.0
# 4          -9999.0          -9999.0            -6.66          -9999.0
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0            -66.6            -6.66  ...              NaN              NaN
# 1            -66.6            -6.66  ...              NaN              NaN
# 2            -66.6            -6.66  ...              NaN              NaN
# 3          -9999.0            -6.66  ...              NaN              NaN
# 4          -9999.0            -6.66  ...              NaN              NaN
#
#    DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
# [5 rows x 47 columns]

# %%
outer_joined.shape
# Out:
# (278130, 47)

# %%
#Dropping columns that have missing data
#Joining only columns that the original DataFrames have in common
inner_joined = pd.concat([climate_temp, climate_precip], join = "inner")
inner_joined.head()
# Out:
#              STATION            STATION_NAME      DATE
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105

# %%
inner_joined.shape
# Out:
# (278130, 3)

# %%
#Rows that have data for all columns in both DataFrames
inner_joined_cols = pd.concat(
    [climate_temp, climate_precip], axis = "columns", join = "inner"
)
inner_joined_cols.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  DLY-SNWD-PCTALL-GE001WI  \
# 0            -7777  ...                        3                    -9999
# 1            -7777  ...                        3                    -9999
# 2            -7777  ...                        3                    -9999
# 3            -7777  ...                        3                        0
# 4            -7777  ...                        3                        0
#
#    DLY-SNWD-PCTALL-GE010WI  DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 0                        0                    -9999                    -9999
# 1                        0                    -9999                    -9999
# 2                        0                    -9999                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  DLY-SNOW-PCTALL-GE100TI  \
# 0                    -9999                    -9999                        0
# 1                    -9999                    -9999                        0
# 2                    -9999                    -9999                        0
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNOW-PCTALL-GE030TI  DLY-SNOW-PCTALL-GE050TI
# 0                    -9999                    -9999
# 1                    -9999                    -9999
# 2                    -9999                    -9999
# 3                        0                        0
# 4                        0                        0
#
# [5 rows x 50 columns]

# %%
inner_joined_cols.shape
# Out:
# (127020, 50)
